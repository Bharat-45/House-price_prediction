# %% [markdown]
# # Bharat Ramchire

# %% [markdown]
# ##LINEAR REGRESSION MODEL:

# %%
import pandas as pd

# %%
House_Price=pd.read_csv("House_Price.csv")

# %% [markdown]
# ##EXPLORARTORY DATA ANALYSIS:

# %%
House_Price.head(10)
# Out:
#    price  crime_rate  resid_area  air_qual  room_num    age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575   65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421   78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185   61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998   45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147   54.2   6.16   5.86
# 5   28.7     0.02985       32.18     0.458     6.430   58.7   6.22   5.80
# 6   22.9     0.08829       37.87     0.524     6.012   66.6   5.87   5.47
# 7   22.1     0.14455       37.87     0.524     6.172   96.1   6.04   5.85
# 8   16.5     0.21124       37.87     0.524     5.631  100.0   6.18   5.85
# 9   18.9     0.17004       37.87     0.524     6.004   85.9   6.67   6.55
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# ...

# %%
House_Price.tail(10)
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 496   19.7     0.28960       39.69     0.585     5.390  72.9   2.86   2.61
# 497   18.3     0.26838       39.69     0.585     5.794  70.6   3.04   2.59
# 498   21.2     0.23912       39.69     0.585     6.019  65.3   2.68   2.25
# 499   17.5     0.17783       39.69     0.585     5.569  73.5   2.46   2.39
# 500   16.8     0.22438       39.69     0.585     6.027  79.7   2.64   2.47
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# ...

# %%
House_Price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
House_Price.shape
# Out:
# (506, 19)

# %%
House_Price.isna().sum()
# Out:
# price          0
# crime_rate     0
# resid_area     0
# air_qual       0
# room_num       0
# age            0
# dist1          0
# dist2          0
# dist3          0
# dist4          0
# teachers       0
# poor_prop      0
# airport        0
# n_hos_beds     8
# n_hot_rooms    0
# waterbody      0
# rainfall       0
# bus_ter        0
# parks          0
# dtype: int64

# %%
House_Price['airport'].value_counts()
# Out:
# YES    279
# NO     227
# Name: airport, dtype: int64

# %%
House_Price['airport'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# YES    55.1%
# NO     44.9%
# Name: airport, dtype: object

# %%
House_Price['waterbody'].value_counts()
# Out:
# River             183
# None              155
# Lake               97
# Lake and River     71
# Name: waterbody, dtype: int64

# %%
House_Price['waterbody'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# River             36.2%
# None              30.6%
# Lake              19.2%
# Lake and River    14.0%
# Name: waterbody, dtype: object

# %%
House_Price['bus_ter'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# YES    100.0%
# Name: bus_ter, dtype: object

# %%
# Conventional way to import seaborn
import seaborn as sns

# To visualise in the notebook
# %matplotlib inline

House_Price['airport'].value_counts().plot(kind='bar')

# %%
House_Price['waterbody'].value_counts().plot(kind='bar')

# %%
House_Price['bus_ter'].value_counts().plot(kind='bar')

# %%
House_Price.drop(['bus_ter'], axis=1, inplace=True)

# %%
House_Price.shape
# Out:
# (506, 18)

# %%
##for distances take a average
House_Price["avg_dist"]=House_Price[["dist1","dist2","dist3","dist4"]].mean(axis=1)

# %%
House_Price.drop(["dist1","dist2","dist3","dist4"], axis=1, inplace=True)

# %%
House_Price.shape
# Out:
# (506, 15)

# %%
House_Price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   teachers     506 non-null    float64
#  7   poor_prop    506 non-null    float64
#  8   airport      506 non-null    object
#  9   n_hos_beds   498 non-null    float64
#  10  n_hot_rooms  506 non-null    float64
#  11  waterbody    506 non-null    object
#  12  rainfall     506 non-null    int64
#  13  parks        506 non-null    float64
#  14  avg_dist     506 non-null    float64
# dtypes: float64(12), int64(1), object(2)
# memory usage: 59.4+ KB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize = (16,10))
sns.heatmap(House_Price.corr(),annot = True)

# %%
# Converting Yes to 1 and No to 0
House_Price['airport'] =House_Price['airport'].map({'YES': 1, 'NO': 0})

# %%
House_Price.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2      24.7
# 1   21.6     0.02731       37.07     0.469     6.421  78.9      22.2
# 2   34.7     0.02729       37.07     0.469     7.185  61.1      22.2
# 3   33.4     0.03237       32.18     0.458     6.998  45.8      21.3
# 4   36.2     0.06905       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  airport  n_hos_beds  n_hot_rooms waterbody  rainfall     parks  \
# 0       4.98        1       5.480      11.1920     River        23  0.049347
# 1       9.14        0       7.332      12.1728      Lake        42  0.046146
# 2       4.03        0       7.394     101.1200      None        38  0.045764
# 3       2.94        1       9.268      11.2672      Lake        45  0.047151
# 4       5.33        0       8.824      11.2896      Lake        55  0.039474
#
#    avg_dist
# 0    4.0875
# 1    4.9675
# 2    4.9675
# 3    6.0650
# 4    6.0625

# %%
House_Price['price'].describe()
# Out:
# count    506.000000
# mean      22.528854
# std        9.182176
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: price, dtype: float64

# %%
##visualaization f the data

# %%
# Conventional way to import seaborn
import seaborn as sns

# To visualise in the notebook
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
House_Price['crime_rate'].describe()
# Out:
# count    506.000000
# mean       3.613524
# std        8.601545
# min        0.006320
# 25%        0.082045
# 50%        0.256510
# 75%        3.677082
# max       88.976200
# Name: crime_rate, dtype: float64

# %%
print(House_Price['crime_rate'].skew())
# Out:
# 5.223148798243851

# %%
sns.boxplot(House_Price['crime_rate'])
plt.show()

# %%
plt.hist(House_Price['crime_rate'],histtype='bar', rwidth=0.9)
# Out:
# (array([439.,  44.,  14.,   1.,   3.,   2.,   0.,   1.,   1.,   1.]),
#  array([6.3200000e-03, 8.9033080e+00, 1.7800296e+01, 2.6697284e+01,
#         3.5594272e+01, 4.4491260e+01, 5.3388248e+01, 6.2285236e+01,
#         7.1182224e+01, 8.0079212e+01, 8.8976200e+01]),
#  <a list of 10 Patch objects>)

# %%
# Cut the window in 2 parts
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
# Add a graph in each part
sns.boxplot(House_Price["crime_rate"], ax=ax_box)
sns.distplot(House_Price["crime_rate"], ax=ax_hist)

# %%
##scatterplot
plt.scatter(x='crime_rate', y='price')
plt.title("crime_rate Vs price")
plt.xlabel("crime_rate")
plt.ylabel("price")
plt.show()

# %%
##pairplot
sns.pairplot(House_Price, x_vars='crime_rate', y_vars='price',size=5, aspect=0.7, kind='scatter')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
##the data is near to zero type of graph is log pattern so data transformation needed.

# %%
##treat the outliers by capping method

# %%
print(House_Price['crime_rate'].quantile(0.50))
print(House_Price['crime_rate'].quantile(0.95))
# Out:
# 0.25651
# 15.78915

# %%
import numpy as np

# %%
House_Price['crime_rate'] = np.where(House_Price['crime_rate'] > 15.78915,20, House_Price['crime_rate'])
House_Price['crime_rate'].describe()
# Out:
# count    506.000000
# mean       3.012323
# std        5.318902
# min        0.006320
# 25%        0.082045
# 50%        0.256510
# 75%        3.677082
# max       20.000000
# Name: crime_rate, dtype: float64

# %%
sns.boxplot(House_Price['crime_rate'])

# %%
##data transformation

# %%
#lets transform
House_Price['crime_rate'] = House_Price['crime_rate'] + 1
#create new column for log transformation
House_Price['log_crime_rate'] = np.log(House_Price['crime_rate'])

# %%
print(House_Price['log_crime_rate'].skew())
# Out:
# 1.102433813741948

# %%
House_Price.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0     1.00632       32.31     0.538     6.575  65.2      24.7
# 1   21.6     1.02731       37.07     0.469     6.421  78.9      22.2
# 2   34.7     1.02729       37.07     0.469     7.185  61.1      22.2
# 3   33.4     1.03237       32.18     0.458     6.998  45.8      21.3
# 4   36.2     1.06905       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  airport  n_hos_beds  n_hot_rooms waterbody  rainfall     parks  \
# 0       4.98        1       5.480      11.1920     River        23  0.049347
# 1       9.14        0       7.332      12.1728      Lake        42  0.046146
# 2       4.03        0       7.394     101.1200      None        38  0.045764
# 3       2.94        1       9.268      11.2672      Lake        45  0.047151
# 4       5.33        0       8.824      11.2896      Lake        55  0.039474
#
#    avg_dist  log_crime_rate
# 0    4.0875        0.006300
# 1    4.9675        0.026944
# ...

# %%
House_Price['resid_area'].describe()
# Out:
# count    506.000000
# mean      41.136779
# std        6.860353
# min       30.460000
# 25%       35.190000
# 50%       39.690000
# 75%       48.100000
# max       57.740000
# Name: resid_area, dtype: float64

# %%
sns.boxplot(House_Price['resid_area'])

# %%
print(House_Price['resid_area'].skew())
# Out:
# 0.2950215678735116

# %%
House_Price['air_qual'].describe()
# Out:
# count    506.000000
# mean       0.554695
# std        0.115878
# min        0.385000
# 25%        0.449000
# 50%        0.538000
# 75%        0.624000
# max        0.871000
# Name: air_qual, dtype: float64

# %%
sns.boxplot(House_Price['air_qual'])

# %%
print(House_Price['air_qual'].skew())
# Out:
# 0.7293079225348785

# %%
##pairplot
sns.pairplot(House_Price, x_vars='air_qual', y_vars='price',size=5, aspect=0.7, kind='scatter')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
House_Price['room_num'].describe()
# Out:
# count    506.000000
# mean       6.284634
# std        0.702617
# min        3.561000
# 25%        5.885500
# 50%        6.208500
# 75%        6.623500
# max        8.780000
# Name: room_num, dtype: float64

# %%
print(House_Price['room_num'].skew())
# Out:
# 0.4036121332887437

# %%
sns.boxplot(House_Price['room_num'])

# %%
print(House_Price['room_num'].quantile(0.05))
print(House_Price['room_num'].quantile(0.95))
# Out:
# 5.314
# 7.5875

# %%
House_Price['room_num'] = np.where(House_Price['room_num'] > 7.5875, 10, House_Price['room_num'])
House_Price['room_num'] = np.where(House_Price['room_num'] < 5.314, 3, House_Price['room_num'])
House_Price['room_num'].describe()
# Out:
# count    506.000000
# mean       6.290905
# std        1.211508
# min        3.000000
# 25%        5.885500
# 50%        6.208500
# 75%        6.623500
# max       10.000000
# Name: room_num, dtype: float64

# %%
sns.boxplot(House_Price['room_num'])

# %%
plt.hist(House_Price['room_num'],histtype='bar', rwidth=0.9)
# Out:
# (array([ 26.,   0.,   0.,  67., 261., 106.,  20.,   0.,   0.,  26.]),
#  array([ 3. ,  3.7,  4.4,  5.1,  5.8,  6.5,  7.2,  7.9,  8.6,  9.3, 10. ]),
#  <a list of 10 Patch objects>)

# %%
sns.boxplot(House_Price['age'])

# %%
print(House_Price['age'].skew())
# Out:
# -0.5989626398812962

# %%
sns.boxplot(House_Price['teachers'])

# %%
print(House_Price['teachers'].quantile(0.50))
print(House_Price['teachers'].quantile(0.95))
# Out:
# 20.95
# 25.3

# %%
House_Price['teachers'] = np.where(House_Price['teachers'] > 25.3, 20.95, House_Price['teachers'])
House_Price['teachers'].describe()
# Out:
# count    506.000000
# mean      21.342787
# std        1.915190
# min       18.000000
# 25%       19.800000
# 50%       20.925000
# 75%       22.550000
# max       25.300000
# Name: teachers, dtype: float64

# %%
sns.boxplot(House_Price['teachers'])

# %%
sns.boxplot(House_Price['poor_prop'])

# %%
print(House_Price['poor_prop'].quantile(0.95))
# Out:
# 26.8075

# %%
House_Price['poor_prop'] = np.where(House_Price['poor_prop'] > 26.8075, 30, House_Price['poor_prop'])
House_Price['poor_prop'].describe()
# Out:
# count    506.000000
# mean      12.616423
# std        7.017667
# min        1.730000
# 25%        6.950000
# 50%       11.360000
# 75%       16.955000
# max       30.000000
# Name: poor_prop, dtype: float64

# %%
sns.boxplot(House_Price['poor_prop'])

# %%
sns.boxplot(House_Price['n_hos_beds'])

# %%
House_Price['n_hos_beds'].isna().sum()
# Out:
# 8

# %%
House_Price['n_hos_beds'] = np.where(House_Price['n_hos_beds'].isnull() == True , np.mean(House_Price['n_hos_beds']), House_Price['n_hos_beds'])

# %%
House_Price['n_hos_beds'].isna().sum()
# Out:
# 0

# %%
House_Price.tail(10)
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 496   19.7     1.28960       39.69     0.585     5.390  72.9      20.8
# 497   18.3     1.26838       39.69     0.585     5.794  70.6      20.8
# 498   21.2     1.23912       39.69     0.585     6.019  65.3      20.8
# 499   17.5     1.17783       39.69     0.585     5.569  73.5      20.8
# 500   16.8     1.22438       39.69     0.585     6.027  79.7      20.8
# 501   22.4     1.06263       41.93     0.573     6.593  69.1      19.0
# 502   20.6     1.04527       41.93     0.573     6.120  76.7      19.0
# 503   23.9     1.06076       41.93     0.573     6.976  91.0      19.0
# 504   22.0     1.10959       41.93     0.573     6.794  89.3      19.0
# 505   19.0     1.04741       41.93     0.573     6.030  80.8      19.0
#
#      poor_prop  airport  n_hos_beds  n_hot_rooms       waterbody  rainfall  \
# 496      21.14        0    7.899767      12.1576           River        44
# ...

# %%
sns.boxplot(House_Price['n_hot_rooms'])

# %%
print(House_Price['n_hot_rooms'].quantile(0.50))
print(House_Price['n_hot_rooms'].quantile(0.95))
# Out:
# 12.719999999999999
# 15.1948

# %%
House_Price['n_hot_rooms'] = np.where(House_Price['n_hot_rooms'] >18.7978, 12.719999999999999, House_Price['n_hot_rooms'])
House_Price['n_hot_rooms'].describe()
# Out:
# count    506.000000
# mean      12.731723
# std        1.676697
# min       10.057600
# 25%       11.189800
# 50%       12.560000
# 75%       14.168200
# max       15.400000
# Name: n_hot_rooms, dtype: float64

# %%
sns.boxplot(House_Price['n_hot_rooms'])

# %%
sns.boxplot(House_Price['rainfall'])

# %%
plt.hist(House_Price['rainfall'],histtype='bar', rwidth=0.9)
# Out:
# (array([ 1.,  0., 17., 79., 78., 55., 68., 66., 61., 81.]),
#  array([ 3. ,  8.7, 14.4, 20.1, 25.8, 31.5, 37.2, 42.9, 48.6, 54.3, 60. ]),
#  <a list of 10 Patch objects>)

# %%
sns.boxplot(House_Price['parks'])

# %%
plt.hist(House_Price['parks'],histtype='bar', rwidth=0.9)
# Out:
# (array([21., 63., 98., 90., 88., 69., 36., 22., 13.,  6.]),
#  array([0.03329176, 0.03863373, 0.0439757 , 0.04931768, 0.05465965,
#         0.06000162, 0.06534359, 0.07068556, 0.07602753, 0.0813695 ,
#         0.08671147]),
#  <a list of 10 Patch objects>)

# %%
print(House_Price['parks'].quantile(0.50))
print(House_Price['parks'].quantile(0.95))
# Out:
# 0.053506539
# 0.07522874275

# %%
House_Price['parks'] = np.where(House_Price['parks'] >0.0862920565, 0.053506539, House_Price['parks'])
House_Price['parks'].describe()
# Out:
# count    506.000000
# mean       0.054388
# std        0.010535
# min        0.033292
# 25%        0.046464
# 50%        0.053490
# 75%        0.061370
# max        0.085078
# Name: parks, dtype: float64

# %%
sns.boxplot(House_Price['parks'])

# %%
plt.figure(figsize = (30,20))
sns.pairplot(House_Price)

# %%
plt.figure(figsize = (16,10))
sns.heatmap(House_Price.corr(),annot = True)

# %%
# we don't need 3 columns.
# we can use drop_first = True to drop the first column from status df.
status = pd.get_dummies(House_Price['waterbody'],drop_first=True)

# %%
#Adding the results to the master dataframe
House_Price= pd.concat([House_Price,status],axis=1)

# %%
House_Price.drop(['waterbody'], axis=1, inplace = True)
House_Price.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0     1.00632       32.31     0.538     6.575  65.2      24.7
# 1   21.6     1.02731       37.07     0.469     6.421  78.9      22.2
# 2   34.7     1.02729       37.07     0.469     7.185  61.1      22.2
# 3   33.4     1.03237       32.18     0.458     6.998  45.8      21.3
# 4   36.2     1.06905       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  airport  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98        1       5.480      11.1920        23  0.049347    4.0875
# 1       9.14        0       7.332      12.1728        42  0.046146    4.9675
# 2       4.03        0       7.394      12.7200        38  0.045764    4.9675
# 3       2.94        1       9.268      11.2672        45  0.047151    6.0650
# 4       5.33        0       8.824      11.2896        55  0.039474    6.0625
#
#    log_crime_rate  Lake and River  None  River
# ...

# %%
House_Price.drop(['crime_rate'], axis=1, inplace = True)
House_Price.head()
# Out:
#    price  resid_area  air_qual  room_num   age  teachers  poor_prop  airport  \
# 0   24.0       32.31     0.538     6.575  65.2      24.7       4.98        1
# 1   21.6       37.07     0.469     6.421  78.9      22.2       9.14        0
# 2   34.7       37.07     0.469     7.185  61.1      22.2       4.03        0
# 3   33.4       32.18     0.458     6.998  45.8      21.3       2.94        1
# 4   36.2       32.18     0.458     7.147  54.2      21.3       5.33        0
#
#    n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  log_crime_rate  \
# 0       5.480      11.1920        23  0.049347    4.0875        0.006300
# 1       7.332      12.1728        42  0.046146    4.9675        0.026944
# 2       7.394      12.7200        38  0.045764    4.9675        0.026924
# 3       9.268      11.2672        45  0.047151    6.0650        0.031857
# 4       8.824      11.2896        55  0.039474    6.0625        0.066770
#
#    Lake and River  None  River
# 0               0     0      1
# ...

# %%
plt.figure(figsize = (16,10))
sns.heatmap(House_Price.corr(),annot = True)

# %% [markdown]
# ##splitting the data into train and testset

# %%
# Putting feature variable to X
X = House_Price[['log_crime_rate', 'resid_area','air_qual', 'room_num', 'age', 'avg_dist', 'teachers', 'poor_prop', 'n_hos_beds', 'n_hot_rooms', 'rainfall', 'parks', 'Lake and River', 'None', 'River']]

# Putting response variable to y
y = House_Price['price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7 , random_state=100)

# %%
X_train
# Out:
#      log_crime_rate  resid_area  air_qual  room_num    age  avg_dist  \
# 463        1.920028       48.10    0.7130     6.513   89.9    2.8025
# 75         0.090864       42.83    0.4370     6.286   45.0    4.5050
# 478        2.418856       48.10    0.6140     6.185   96.7    2.1700
# 199        0.031014       31.47    0.4030     6.975   15.3    7.6525
# 84         0.049352       34.49    0.4490     6.389   48.0    4.7800
# ..              ...         ...       ...       ...    ...       ...
# 343        0.025112       33.78    0.4840     6.696   56.4    5.7325
# 359        1.660380       48.10    0.7700     6.112   81.3    2.5075
# 323        0.249918       37.38    0.4930     5.708   74.3    4.7200
# 280        0.035155       33.33    0.4429    10.000   64.5    4.6950
# 8          0.191645       37.87    0.5240     5.631  100.0    6.0825
#
#      teachers  poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  \
# ...

# %%
X_test
# Out:
#      log_crime_rate  resid_area  air_qual  room_num    age  avg_dist  \
# 198        0.036987       31.52    0.4040     7.274   38.3    7.3100
# 229        0.365878       36.20    0.5040     6.552   21.4    3.3725
# 502        0.044275       41.93    0.5730     6.120   76.7    2.2875
# 31         0.856422       38.14    0.5380     6.072  100.0    4.1750
# 315        0.225988       39.90    0.5440     5.705   77.7    3.9450
# ..              ...         ...       ...       ...    ...       ...
# 272        0.108496       36.96    0.4640     6.538   58.7    3.9175
# 124        0.093937       55.65    0.5810     5.879   95.8    2.0075
# 178        0.064307       34.05    0.5100     6.860   74.4    2.9125
# 447        2.391040       48.10    0.7400     6.251   96.6    2.1975
# 282        0.059485       33.33    0.4429    10.000   49.7    5.2100
#
#      teachers  poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  \
# ...

# %%
y_train
# Out:
# 463    20.2
# 75     21.4
# 478    14.6
# 199    34.9
# 84     23.9
#        ...
# 343    23.9
# 359    22.6
# 323    18.5
# 280    45.4
# 8      16.5
# Name: price, Length: 354, dtype: float64

# %%
y_test
# Out:
# 198    34.6
# 229    31.5
# 502    20.6
# 31     14.5
# 315    16.2
#        ...
# 272    24.4
# 124    18.8
# 178    29.9
# 447    12.6
# 282    46.0
# Name: price, Length: 152, dtype: float64

# %%
print(X_train.shape)
# Out:
# (354, 15)

# %%
#performing linear regression model

# %%
from sklearn.linear_model import LinearRegression

# %%
# Representing LinearRegression as lr(Creating LinearRegression Object)
lm = LinearRegression()

# %%
lm
# Out:
# LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# 12.067811461803934

# %%
coeff_df = pd.DataFrame(lm.coef_,X_test.columns,columns=['Coefficient'])
coeff_df
# Out:
#                 Coefficient
# log_crime_rate     0.109929
# resid_area        -0.225562
# air_qual         -11.018101
# room_num           2.418593
# age               -0.010585
# avg_dist          -1.286739
# teachers           0.829041
# poor_prop         -0.575023
# n_hos_beds         0.247433
# n_hot_rooms        0.069787
# rainfall           0.026903
# parks             47.982738
# Lake and River    -1.245476
# None              -0.705680
# River             -1.072064

# %%
# Making predictions using the model
y_pred = lm.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r_squared = r2_score(y_test, y_pred)

# %%
print('Mean_Squared_Error :' ,mse)
print('r_square_value :',r_squared)
# Out:
# Mean_Squared_Error : 33.93974567489278
# r_square_value : 0.6647217279281383

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
# VIF dataframe 
vif_data = pd.DataFrame() 
vif_data["feature"] = X.columns
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X.values, i) 
                          for i in range(len(X.columns))] 
  
print(vif_data)
# Out:
#            feature         VIF
# 0   log_crime_rate    4.413836
# 1       resid_area   93.146608
# 2         air_qual  208.584741
# 3         room_num   38.451747
# 4              age   20.847779
# 5         avg_dist   11.127211
# 6         teachers  119.371454
# 7        poor_prop   11.153761
# 8       n_hos_beds   28.867817
# 9      n_hot_rooms   50.664710
# 10        rainfall   11.138695
# 11           parks  158.716477
# 12  Lake and River    1.765023
# 13            None    2.598936
# 14           River    2.889374

# %%
import statsmodels.api as sm
X_train_sm = X_train
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_sm = sm.add_constant(X_train_sm)
# create a fitted model in one line
lm_1 = sm.OLS(y_train,X_train_sm).fit()

# print the coefficients
lm_1.params
# Out:
# const             12.067811
# log_crime_rate     0.109929
# resid_area        -0.225562
# air_qual         -11.018101
# room_num           2.418593
# age               -0.010585
# avg_dist          -1.286739
# teachers           0.829041
# poor_prop         -0.575023
# n_hos_beds         0.247433
# n_hot_rooms        0.069787
# rainfall           0.026903
# parks             47.982738
# Lake and River    -1.245476
# None              -0.705680
# River             -1.072064
# dtype: float64

# %%
print(lm_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.717
# Model:                            OLS   Adj. R-squared:                  0.704
# Method:                 Least Squares   F-statistic:                     56.96
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):           6.46e-83
# Time:                        19:03:13   Log-Likelihood:                -1047.5
# No. Observations:                 354   AIC:                             2127.
# Df Residuals:                     338   BIC:                             2189.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             12.0678      6.152      1.962      0.051      -0.033      24.168
# ...

# %%
#Actual vs Predicted
c = [i for i in range(1,153,1)]
fig = plt.figure()
plt.plot(c,y_test, color="blue", linewidth=2.5, linestyle="-")
plt.plot(c,y_pred, color="red",  linewidth=2.5, linestyle="-")
fig.suptitle('Actual and Predicted', fontsize=20)              
plt.xlabel('Index', fontsize=18)                               
plt.ylabel('price', fontsize=16)
# Out:
# Text(0, 0.5, 'price')

# %%
X_train_new = X_train[['log_crime_rate', 'resid_area', 'room_num', 'age', 'avg_dist', 'teachers', 'poor_prop', 'n_hos_beds', 'n_hot_rooms', 'rainfall', 'parks', 'Lake and River', 'None', 'River']]
X_test_new = X_test[['log_crime_rate', 'resid_area','room_num', 'age', 'avg_dist', 'teachers', 'poor_prop', 'n_hos_beds', 'n_hot_rooms', 'rainfall', 'parks', 'Lake and River', 'None', 'River']]

# %%
##build the model
lm.fit(X_train_new,y_train)
# Out:
# LinearRegression()

# %%
#making prediction using model
y_pred_new = lm.predict(X_test_new)

# %%
#Actual vs Predicted
c = [i for i in range(1,153,1)]
fig = plt.figure()
plt.plot(c,y_test, color="blue", linewidth=2.5, linestyle="-")
plt.plot(c,y_pred_new, color="red",  linewidth=2.5, linestyle="-")
fig.suptitle('Actual and Predicted', fontsize=20)              
plt.xlabel('Index', fontsize=18)                               
plt.ylabel('Sales', fontsize=16)
# Out:
# Text(0, 0.5, 'Sales')

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred_new)
r_squared = r2_score(y_test, y_pred_new)

# %%
print('Mean_Squared_Error :' ,mse)
print('r_square_value :',r_squared)
# Out:
# Mean_Squared_Error : 34.46727643752991
# r_square_value : 0.6595104454319182

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
# VIF dataframe 
vif_data = pd.DataFrame() 
vif_data["feature"] = X_train_new.columns
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X_train_new.values, i) 
                          for i in range(len(X_train_new.columns))] 
  
print(vif_data)
# Out:
#            feature         VIF
# 0   log_crime_rate    4.225189
# 1       resid_area   86.581996
# 2         room_num   39.415047
# 3              age   20.900560
# 4         avg_dist   11.458911
# 5         teachers  111.398418
# 6        poor_prop   11.340992
# 7       n_hos_beds   30.461019
# 8      n_hot_rooms   51.966735
# 9         rainfall   11.553034
# 10           parks   79.057190
# 11  Lake and River    1.765028
# 12            None    2.587356
# 13           River    2.973577

# %%
X_train_final = X_train_new
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_final = sm.add_constant(X_train_final)
# create a fitted model in one line
lm_final = sm.OLS(y_train,X_train_final).fit()

print(lm_final.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.714
# Model:                            OLS   Adj. R-squared:                  0.702
# Method:                 Least Squares   F-statistic:                     60.43
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):           3.74e-83
# Time:                        19:03:14   Log-Likelihood:                -1049.2
# No. Observations:                 354   AIC:                             2128.
# Df Residuals:                     339   BIC:                             2186.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             11.1584      6.149      1.815      0.070      -0.937      23.254
# ...

# %%
X_train_new1 = X_train[['log_crime_rate', 'resid_area', 'room_num', 'age', 'avg_dist', 'poor_prop', 'n_hos_beds', 'n_hot_rooms', 'rainfall', 'parks', 'Lake and River', 'None', 'River']]
X_test_new1 = X_test[['log_crime_rate', 'resid_area', 'room_num', 'age', 'avg_dist', 'poor_prop', 'n_hos_beds', 'n_hot_rooms', 'rainfall', 'parks', 'Lake and River', 'None', 'River']]

# %%
##build the model
lm.fit(X_train_new1,y_train)
# Out:
# LinearRegression()

# %%
#making prediction using model
y_pred_new1 = lm.predict(X_test_new1)

# %%
#Actual vs Predicted
c = [i for i in range(1,153,1)]
fig = plt.figure()
plt.plot(c,y_test, color="blue", linewidth=2.5, linestyle="-")
plt.plot(c,y_pred_new1, color="red",  linewidth=2.5, linestyle="-")
fig.suptitle('Actual and Predicted', fontsize=20)              
plt.xlabel('Index', fontsize=18)                               
plt.ylabel('price', fontsize=16)
# Out:
# Text(0, 0.5, 'price')

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred_new1)
r_squared = r2_score(y_test, y_pred_new1)

# %%
print('Mean_Squared_Error :' ,mse)
print('r_square_value :',r_squared)
# Out:
# Mean_Squared_Error : 36.594584746621514
# r_square_value : 0.6384955485947867

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
# VIF dataframe 
vif_data = pd.DataFrame() 
vif_data["feature"] = X_train_new1.columns
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X_train_new1.values, i) 
                          for i in range(len(X_train_new1.columns))] 
  
print(vif_data)
# Out:
#            feature        VIF
# 0   log_crime_rate   3.749887
# 1       resid_area  80.247451
# 2         room_num  35.028517
# 3              age  20.898065
# 4         avg_dist   9.885552
# 5        poor_prop  11.212078
# 6       n_hos_beds  29.067043
# 7      n_hot_rooms  50.274991
# 8         rainfall  11.509879
# 9            parks  74.337693
# 10  Lake and River   1.764644
# 11            None   2.587356
# 12           River   2.922241

# %%
X_train_final = X_train_new1
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_final = sm.add_constant(X_train_final)
# create a fitted model in one line
lm_final = sm.OLS(y_train,X_train_final).fit()

print(lm_final.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.691
# Model:                            OLS   Adj. R-squared:                  0.679
# Method:                 Least Squares   F-statistic:                     58.55
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):           1.64e-78
# Time:                        19:03:16   Log-Likelihood:                -1062.7
# No. Observations:                 354   AIC:                             2153.
# Df Residuals:                     340   BIC:                             2207.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             29.3050      5.245      5.587      0.000      18.988      39.622
# ...

# %%
X_train_new2 = X_train[['log_crime_rate', 'room_num', 'age', 'avg_dist', 'teachers', 'poor_prop', 'n_hos_beds', 'n_hot_rooms', 'rainfall', 'parks', 'Lake and River', 'None', 'River']]
X_test_new2 = X_test[['log_crime_rate','room_num', 'age', 'avg_dist', 'teachers', 'poor_prop', 'n_hos_beds', 'n_hot_rooms', 'rainfall', 'parks', 'Lake and River', 'None', 'River']]

# %%
##build the model
lm.fit(X_train_new2,y_train)
# Out:
# LinearRegression()

# %%
#making prediction using model
y_pred_new2 = lm.predict(X_test_new2)

# %%
#Actual vs Predicted
c = [i for i in range(1,153,1)]
fig = plt.figure()
plt.plot(c,y_test, color="blue", linewidth=2.5, linestyle="-")
plt.plot(c,y_pred_new2, color="red",  linewidth=2.5, linestyle="-")
fig.suptitle('Actual and Predicted', fontsize=20)              
plt.xlabel('Index', fontsize=18)                               
plt.ylabel('price', fontsize=16)
# Out:
# Text(0, 0.5, 'price')

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred_new2)
r_squared = r2_score(y_test, y_pred_new2)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
# VIF dataframe 
vif_data = pd.DataFrame() 
vif_data["feature"] = X_train_new2.columns
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X_train_new2.values, i) 
                          for i in range(len(X_train_new2.columns))] 
  
print(vif_data)
# Out:
#            feature         VIF
# 0   log_crime_rate    3.985421
# 1         room_num   39.179937
# 2              age   20.845627
# 3         avg_dist   11.317820
# 4         teachers  103.248245
# 5        poor_prop   10.843147
# 6       n_hos_beds   29.567997
# 7      n_hot_rooms   51.665858
# 8         rainfall   11.539312
# 9            parks   67.703679
# 10  Lake and River    1.760343
# 11            None    2.556092
# 12           River    2.972688

# %%
X_train_final = X_train_new2
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_final = sm.add_constant(X_train_final)
# create a fitted model in one line
lm_final = sm.OLS(y_train,X_train_final).fit()

print(lm_final.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.702
# Model:                            OLS   Adj. R-squared:                  0.691
# Method:                 Least Squares   F-statistic:                     61.60
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):           4.34e-81
# Time:                        19:03:19   Log-Likelihood:                -1056.4
# No. Observations:                 354   AIC:                             2141.
# Df Residuals:                     340   BIC:                             2195.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.0331      5.485     -0.006      0.995     -10.822      10.756
# ...

# %%
X_train_new3 = X_train[['log_crime_rate', 'room_num', 'age', 'avg_dist', 'teachers', 'poor_prop', 'n_hos_beds','n_hot_rooms','rainfall', 'Lake and River', 'None', 'River']]
X_test_new3 = X_test[['log_crime_rate','room_num', 'age', 'avg_dist', 'teachers', 'poor_prop', 'n_hos_beds', 'n_hot_rooms', 'rainfall','Lake and River', 'None', 'River']]

# %%
##build the model
lm.fit(X_train_new3,y_train)
# Out:
# LinearRegression()

# %%
#making prediction using model
y_pred_new3 = lm.predict(X_test_new3)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred_new3)
r_squared = r2_score(y_test, y_pred_new3)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
# VIF dataframe 
vif_data = pd.DataFrame() 
vif_data["feature"] = X_train_new3.columns
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X_train_new3.values, i) 
                          for i in range(len(X_train_new3.columns))] 
  
print(vif_data)
# Out:
#            feature        VIF
# 0   log_crime_rate   3.444437
# 1         room_num  38.581407
# 2              age  19.200760
# 3         avg_dist  10.879226
# 4         teachers  87.600546
# 5        poor_prop  10.513868
# 6       n_hos_beds  29.521390
# 7      n_hot_rooms  49.091717
# 8         rainfall  11.393435
# 9   Lake and River   1.759780
# 10            None   2.553724
# 11           River   2.970932

# %%
X_train_final = X_train_new3
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_final = sm.add_constant(X_train_final)
# create a fitted model in one line
lm_final = sm.OLS(y_train,X_train_final).fit()

print(lm_final.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.700
# Model:                            OLS   Adj. R-squared:                  0.690
# Method:                 Least Squares   F-statistic:                     66.33
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):           1.50e-81
# Time:                        19:03:22   Log-Likelihood:                -1057.5
# No. Observations:                 354   AIC:                             2141.
# Df Residuals:                     341   BIC:                             2191.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -2.7112      5.181     -0.523      0.601     -12.901       7.479
# ...

# %%
X_train_new4 = X_train[['log_crime_rate', 'resid_area', 'room_num', 'age', 'avg_dist', 'teachers', 'poor_prop', 'n_hos_beds',  'rainfall','Lake and River', 'None', 'River']]
X_test_new4 = X_test[['log_crime_rate', 'resid_area', 'room_num', 'age', 'avg_dist', 'teachers', 'poor_prop', 'n_hos_beds',  'rainfall',  'Lake and River', 'None', 'River']]

# %%
##build the model
lm.fit(X_train_new4,y_train)
# Out:
# LinearRegression()

# %%
#making prediction using model
y_pred_new4 = lm.predict(X_test_new4)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred_new3)
r_squared = r2_score(y_test, y_pred_new4)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
# VIF dataframe 
vif_data = pd.DataFrame() 
vif_data["feature"] = X_train_new4.columns
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X_train_new4.values, i) 
                          for i in range(len(X_train_new4.columns))] 
  
print(vif_data)
# Out:
#            feature        VIF
# 0   log_crime_rate   3.935420
# 1       resid_area  72.314471
# 2         room_num  38.270722
# 3              age  19.581632
# 4         avg_dist  10.951361
# 5         teachers  98.992810
# 6        poor_prop  11.267442
# 7       n_hos_beds  29.373127
# 8         rainfall  11.293122
# 9   Lake and River   1.754751
# 10            None   2.572563
# 11           River   2.965779

# %%
X_train_final = X_train_new4
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_final = sm.add_constant(X_train_final)
# create a fitted model in one line
lm_final = sm.OLS(y_train,X_train_final).fit()

print(lm_final.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.713
# Model:                            OLS   Adj. R-squared:                  0.703
# Method:                 Least Squares   F-statistic:                     70.76
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):           6.81e-85
# Time:                        19:03:26   Log-Likelihood:                -1049.4
# No. Observations:                 354   AIC:                             2125.
# Df Residuals:                     341   BIC:                             2175.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             12.0769      5.375      2.247      0.025       1.504      22.650
# ...

# %%
X_train_new5 = X_train[['log_crime_rate', 'resid_area', 'room_num', 'age', 'avg_dist', 'teachers', 'poor_prop',  'rainfall','Lake and River', 'None', 'River']]
X_test_new5 = X_test[['log_crime_rate', 'resid_area', 'room_num', 'age', 'avg_dist', 'teachers', 'poor_prop',  'rainfall',  'Lake and River', 'None', 'River']]

# %%
##build the model
lm.fit(X_train_new5,y_train)
# Out:
# LinearRegression()

# %%
#making prediction using model
y_pred_new5 = lm.predict(X_test_new5)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred_new5)
r_squared = r2_score(y_test, y_pred_new5)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
# VIF dataframe 
vif_data = pd.DataFrame() 
vif_data["feature"] = X_train_new5.columns
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X_train_new5.values, i) 
                          for i in range(len(X_train_new5.columns))] 
  
print(vif_data)
# Out:
#            feature        VIF
# 0   log_crime_rate   3.934720
# 1       resid_area  70.125169
# 2         room_num  37.818662
# 3              age  19.519138
# 4         avg_dist  10.833976
# 5         teachers  93.117424
# 6        poor_prop  11.264474
# 7         rainfall  11.161735
# 8   Lake and River   1.754045
# 9             None   2.570933
# 10           River   2.964874

# %%
X_train_final = X_train_new5
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_final = sm.add_constant(X_train_final)
# create a fitted model in one line
lm_final = sm.OLS(y_train,X_train_final).fit()

print(lm_final.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.712
# Model:                            OLS   Adj. R-squared:                  0.702
# Method:                 Least Squares   F-statistic:                     76.74
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):           2.18e-85
# Time:                        19:03:29   Log-Likelihood:                -1050.5
# No. Observations:                 354   AIC:                             2125.
# Df Residuals:                     342   BIC:                             2172.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             13.9352      5.232      2.663      0.008       3.644      24.227
# ...

# %%
X_train_new6 = X_train[['log_crime_rate', 'resid_area', 'room_num', 'avg_dist', 'teachers', 'poor_prop',  'rainfall','Lake and River', 'None', 'River']]
X_test_new6 = X_test[['log_crime_rate', 'resid_area', 'room_num',  'avg_dist', 'teachers', 'poor_prop',  'rainfall',  'Lake and River', 'None', 'River']]

# %%
##build the model
lm.fit(X_train_new6,y_train)
# Out:
# LinearRegression()

# %%
#making prediction using model
y_pred_new6 = lm.predict(X_test_new6)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred_new6)
r_squared = r2_score(y_test, y_pred_new6)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
# VIF dataframe 
vif_data = pd.DataFrame() 
vif_data["feature"] = X_train_new6.columns
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X_train_new6.values, i) 
                          for i in range(len(X_train_new6.columns))] 
  
print(vif_data)
# Out:
#           feature        VIF
# 0  log_crime_rate   3.933761
# 1      resid_area  67.701325
# 2        room_num  35.385530
# 3        avg_dist   7.654280
# 4        teachers  91.950757
# 5       poor_prop   9.526980
# 6        rainfall  11.044683
# 7  Lake and River   1.753868
# 8            None   2.567224
# 9           River   2.963674

# %%
X_train_final = X_train_new6
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_final = sm.add_constant(X_train_final)
# create a fitted model in one line
lm_final = sm.OLS(y_train,X_train_final).fit()

print(lm_final.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.711
# Model:                            OLS   Adj. R-squared:                  0.702
# Method:                 Least Squares   F-statistic:                     84.23
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):           4.33e-86
# Time:                        19:03:32   Log-Likelihood:                -1051.2
# No. Observations:                 354   AIC:                             2124.
# Df Residuals:                     343   BIC:                             2167.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             12.8513      5.145      2.498      0.013       2.732      22.971
# ...

# %%
X_train_new7 = X_train[['log_crime_rate', 'resid_area', 'room_num', 'avg_dist', 'teachers', 'poor_prop', 'Lake and River', 'None', 'River']]
X_test_new7 = X_test[['log_crime_rate', 'resid_area', 'room_num',  'avg_dist', 'teachers', 'poor_prop', 'Lake and River', 'None', 'River']]

# %%
##build the model
lm.fit(X_train_new7,y_train)
# Out:
# LinearRegression()

# %%
#making prediction using model
y_pred_new7 = lm.predict(X_test_new7)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred_new7)
r_squared = r2_score(y_test, y_pred_new7)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
# VIF dataframe 
vif_data = pd.DataFrame() 
vif_data["feature"] = X_train_new7.columns
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X_train_new7.values, i) 
                          for i in range(len(X_train_new7.columns))] 
  
print(vif_data)
# Out:
#           feature        VIF
# 0  log_crime_rate   3.931158
# 1      resid_area  66.395453
# 2        room_num  35.348971
# 3        avg_dist   7.635744
# 4        teachers  89.492692
# 5       poor_prop   9.522701
# 6  Lake and River   1.728385
# 7            None   2.567216
# 8           River   2.963153

# %%
X_train_final = X_train_new7
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_final = sm.add_constant(X_train_final)
# create a fitted model in one line
lm_final = sm.OLS(y_train,X_train_final).fit()

print(lm_final.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.709
# Model:                            OLS   Adj. R-squared:                  0.702
# Method:                 Least Squares   F-statistic:                     93.26
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):           9.45e-87
# Time:                        19:03:35   Log-Likelihood:                -1052.0
# No. Observations:                 354   AIC:                             2124.
# Df Residuals:                     344   BIC:                             2163.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             14.3705      5.004      2.872      0.004       4.529      24.212
# ...

# %%
X_train_new8 = X_train[['resid_area', 'avg_dist', 'room_num', 'teachers', 'poor_prop', ]]
X_test_new8 = X_test[['resid_area', 'avg_dist', 'room_num', 'teachers',  'poor_prop', ]]

# %%
##build the model
lm.fit(X_train_new8,y_train)
# Out:
# LinearRegression()

# %%
#making prediction using model
y_pred_new8 = lm.predict(X_test_new8)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred_new8)
r_squared = r2_score(y_test, y_pred_new8)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
# VIF dataframe 
vif_data = pd.DataFrame() 
vif_data["feature"] = X_train_new8.columns
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X_train_new8.values, i) 
                          for i in range(len(X_train_new8.columns))] 
  
print(vif_data)
# Out:
#       feature        VIF
# 0  resid_area  53.872463
# 1    avg_dist   7.237144
# 2    room_num  35.116549
# 3    teachers  79.141120
# 4   poor_prop   8.551298

# %%
X_train_final = X_train_new8
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_final = sm.add_constant(X_train_final)
# create a fitted model in one line
lm_final = sm.OLS(y_train,X_train_final).fit()

print(lm_final.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.707
# Model:                            OLS   Adj. R-squared:                  0.702
# Method:                 Least Squares   F-statistic:                     167.6
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):           2.24e-90
# Time:                        19:03:37   Log-Likelihood:                -1053.6
# No. Observations:                 354   AIC:                             2119.
# Df Residuals:                     348   BIC:                             2142.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.3006      4.951      2.687      0.008       3.564      23.037
# ...

# %% [markdown]
# ##RFE model

# %%
# Importing RFE and LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
# Running RFE with the output number of the variable equal to 5
lm = LinearRegression()
rfe = RFE(lm, 5)             # running RFE
rfe = rfe.fit(X_train, y_train)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass n_features_to_select=5 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "

# %%
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [False False  True  True False  True  True False False False False  True
#  False False False]
# [ 8  7  1  1 11  1  1  5  6  9 10  1  2  3  4]

# %%
col = X_train.columns[rfe.support_]

# %%
col
# Out:
# Index(['air_qual', 'room_num', 'avg_dist', 'teachers', 'parks'], dtype='object')

# %%
#BUILDING MODEL::
# Creating X_test dataframe with RFE selected variables
X_train_rfe = X_train[col]

# %%
# Adding a constant variable 
import statsmodels.api as sm  
X_train_rfe = sm.add_constant(X_train_rfe)

# %%
lm = sm.OLS(y_train,X_train_rfe).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.588
# Model:                            OLS   Adj. R-squared:                  0.582
# Method:                 Least Squares   F-statistic:                     99.19
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):           9.03e-65
# Time:                        19:03:42   Log-Likelihood:                -1113.9
# No. Observations:                 354   AIC:                             2240.
# Df Residuals:                     348   BIC:                             2263.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -9.0835      5.101     -1.781      0.076     -19.117       0.950
# ...

# %%
train_rfe=X_train[['air_qual', 'room_num', 'avg_dist', 'teachers', 'parks' ]]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
# VIF dataframe 
vif_data = pd.DataFrame() 
vif_data["feature"] = train_rfe.columns
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(train_rfe.values, i) 
                          for i in range(len(train_rfe.columns))] 
  
print(vif_data)
# Out:
#     feature         VIF
# 0  air_qual  145.235027
# 1  room_num   27.378389
# 2  avg_dist    9.120770
# 3  teachers   81.765195
# 4     parks  141.891775

# %%
# Importing RFE and LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
# Running RFE with the output number of the variable equal to 5
lm = LinearRegression()
rfe = RFE(lm, 9)             # running RFE
rfe = rfe.fit(X_train, y_train)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass n_features_to_select=9 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "

# %%
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [False False  True  True False  True  True  True False False False  True
#   True  True  True]
# [4 3 1 1 7 1 1 1 2 5 6 1 1 1 1]

# %%
col = X_train.columns[rfe.support_]

# %%
col
# Out:
# Index(['air_qual', 'room_num', 'avg_dist', 'teachers', 'poor_prop', 'parks',
#        'Lake and River', 'None', 'River'],
#       dtype='object')

# %%
#BUILDING MODEL::
# Creating X_test dataframe with RFE selected variables
X_train_rfe = X_train[col]

# %%
# Adding a constant variable 
import statsmodels.api as sm  
X_train_rfe = sm.add_constant(X_train_rfe)

# %%
lm = sm.OLS(y_train,X_train_rfe).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.702
# Model:                            OLS   Adj. R-squared:                  0.695
# Method:                 Least Squares   F-statistic:                     90.22
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):           5.08e-85
# Time:                        19:03:47   Log-Likelihood:                -1056.1
# No. Observations:                 354   AIC:                             2132.
# Df Residuals:                     344   BIC:                             2171.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              7.7535      4.633      1.673      0.095      -1.360      16.867
# ...

# %%
X_train_new9 = X_train[['room_num', 'avg_dist', 'teachers', 'poor_prop', 'parks', 'Lake and River', 'None', 'River' ]]
X_test_new9= X_test[['room_num', 'avg_dist', 'teachers', 'poor_prop', 'parks', 'Lake and River', 'None', 'River']]

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression
lm
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
##build the model
lm.fit(X_train_new9,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-196-3dc711f20fdc> in <module>
#       1 ##build the model
# ----> 2 lm.fit(X_train_new9,y_train)
#
# TypeError: fit() missing 1 required positional argument: 'y'

# %%
#making prediction using model
y_pred_new9 = lm.predict(X_test_new9)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred_new9)
r_squared = r2_score(y_test, y_pred_new9)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
# VIF dataframe 
vif_data = pd.DataFrame() 
vif_data["feature"] = X_train_new9.columns
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X_train_new9.values, i) 
                          for i in range(len(X_train_new9.columns))] 
  
print(vif_data)
# Out:
#           feature        VIF
# 0        room_num  35.694667
# 1        avg_dist   7.940915
# 2        teachers  78.813643
# 3       poor_prop   8.200421
# 4           parks  47.070357
# 5  Lake and River   1.718448
# 6            None   2.531951
# 7           River   2.959849

# %%
X_train_final = X_train_new9
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X_train_final = sm.add_constant(X_train_final)
# create a fitted model in one line
lm_final = sm.OLS(y_train,X_train_final).fit()

print(lm_final.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.696
# Model:                            OLS   Adj. R-squared:                  0.689
# Method:                 Least Squares   F-statistic:                     98.67
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):           2.03e-84
# Time:                        19:03:52   Log-Likelihood:                -1060.0
# No. Observations:                 354   AIC:                             2138.
# Df Residuals:                     345   BIC:                             2173.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              4.9217      4.561      1.079      0.281      -4.049      13.892
# ...
